# %% [markdown]
# # RL
# by omarelsayed

# %% [markdown]
# # Recall in MDP the process is given by :
# ![image.png](attachment:image.png)

# %% [markdown]
# # If you take out the Transition T(s,a,s') and the Reward(s,a,s') You get reinforcement learning ! that's typicaly the environment , you don't know how well u go to other states " T(s,a,s') " And you don't know the best reward value for each state , and the state space can be continuos like for example , moving a robot arm , the state is the angle of the arm at any point in time , you can't define a reward for something like that

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # we are going to show 4 algorithms :
# # 1- Model based Monte Carlo
# # 2- Model-free Monte Carlo
# # 3- SARSA
# # 4- Q-Learning !
# # they are very close to each other

# %% [markdown]
# # So , a good idea to start with , we learnt about the MDP , can't we define an MDP from DATA ? after that we can apply policy evaluation and value evaluation discussed before right? Seems very smart , and in continuos spaces you are going to collect alot of data

# %% [markdown]
# # This is called Model Base - Monte Carlo
# # Estimation of : T(s,a,s') , and R(s,a,s')
# # Then doing Value Iteration to find the best policy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Transition is found by the number of times i go to an s' by taking action a from s
# # this converges after alot of iterations , Millions so it's not very goot but a good start point
# # Reward : is just the average of what you get when you go to that s' from s

# %% [markdown]
# # Model Free Monte Carlo :
# # Directly Estimating Qopt From Data by the following algorithm :
