# %% [markdown]
# # Data Sampling
# by omar
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bias
# ### Statistical bias refers to measurement or sampling errors that are systematic and produced by the measurement or sampling process. An important distinction should be made between errors due to random chance, and errors due to bias.
# ![image.png](attachment:image.png)

# %% [markdown]
# # Quality vs Quantity in big data?
# In the era of big data, it is sometimes surprising that smaller is better. Time and
# effort spent on random sampling not only reduce bias, but also allow greater
# attention to data exploration and data quality. For example, missing data and
# outliers may contain useful information. It might be prohibitively expensive to
# track down missing values or evaluate outliers in millions of records, but doing
# so in a sample of several thousand records may be feasible. Data plotting and
# manual inspection bog down if there is too much data.
# ![image.png](attachment:image.png)

# %% [markdown]
# ### KEY IDEAS
# Specifying a hypothesis, then collecting data following randomization and random sampling principles, ensures against bias.
# All other forms of data analysis run the risk of bias resulting from the data collection/analysis process (repeated running of models in data
# mining, data snooping in research, and after-the-fact selection of
# interesting events).

# %% [markdown]
# # Sampling
# ## Population Distribtuion : the overall idea we are trying to study and estimate
# ## Sample Distribution : the distribution of the samples taken from the population
# ## Sample Size : how many data point we gather for each sample
# # Note that Sample is of size n "sample size" , not a single point
# ## Sample Distribution of sample mean : the mean of every sample.
# ##

# %% [markdown]
# # Central Limit Theorem
# ### 1 - Given a population with mean and standard deviation sigma :
# ### If you take sample from this population with n larger than 30 , THE MEAN OF THE SAMPLE MEANS IS GOING TO EQUAL THE POPULATION MEAN #1
# ### THEORY 2 - You can get close to the population's distribution if the samples increase
# ### Theory 3 - You can also estimate the std if the population from the samples means .

# %% [markdown]
# ![1_DfBsmbGDS72leAVaV37uKg.png](attachment:1_DfBsmbGDS72leAVaV37uKg.png)

# %% [markdown]
# ![CLT_1E8.png](attachment:CLT_1E8.png)

# %% [markdown]
# ![1_tJoyMMcdILCO8PQJ6d5RRA.jpg](attachment:1_tJoyMMcdILCO8PQJ6d5RRA.jpg)

# %% [markdown]
# # Why is this useful ? because we can apply alot on normal distribution like z - charts , etc.. that can't be applied on other complex shapes.

# %% [markdown]
# # Central Limit Theorem
# ### This phenomenon is termed the central limit theorem. It says that the means
# ### drawn from multiple samples will resemble the familiar bell-shaped normal
# ### curve (see “Normal Distribution”), even if the source population is not normally
# ### distributed, provided that the sample size is large enough and the departure of
# ### the data from normality is not too great. The central limit theorem allows
# ### normal-approximation formulas like the t-distribution to be used in calculating
# ### sampling distributions for inference—that is, confidence intervals and hypothesis tests.
# ### The central limit theorem receives a lot of attention in traditional statistics texts because it underlies the machinery of hypothesis tests and confidence intervals, which themselves consume half the space in such texts. Data scientists should be aware of this role, but, since formal hypothesis tests and confidence intervals play a small role in data science, and the bootstrap is available in any case, the central limit theorem is not so central in the practice of data science.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import scipy.stats as st

#define sample data
data = [12, 12, 13, 13, 15, 16, 17, 22, 23, 25, 26, 27, 28, 28, 29]
# Out:
# (16.75776979778498, 24.042230202215016)

# %%
st.norm.interval(0.95, loc=np.mean(data), scale=np.std(data)/np.sqrt(100))
# Out:
# (19.15463861689003, 21.645361383109968)

# %%
np.mean(data)
# Out:
# 20.4
