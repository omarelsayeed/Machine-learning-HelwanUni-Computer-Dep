# %% [markdown]
# #### <font color='454545'>Written by:</font>  <font color='B3BFFF'>Basma Abd-Elhalem</font>

# %% [markdown]
# ## <font color='454545'>Neural Networks</font>
#
# Neural networks are parallel computing devices,The main objective is to develop a system to perform various computational tasks faster than the traditional systems. These tasks include pattern recognition and classification, approximation, optimization, and data clustering.
# There are many variants of neural networks, such as convolutional neural networks (CNN), recurrent neural networks (RNN), transformers, and countless others, But the first step to understanding any of them is to build up the simplest, plain form with no added frills.
#
#
# ## <font color='454545'>Artificial Neural Network</font>
#
# Artificial Neural Network ANN is an efficient computing system whose central theme is borrowed from the analogy of biological neural networks. ANNs are also named as “artificial neural systems,” or “parallel distributed processing systems,” or “connectionist systems.” ANN acquires a large collection of units that are interconnected in some pattern to allow communication between the units. These units, also referred to as nodes or neurons, are simple processors which operate in parallel.
# neurons are basically computational units that take inputs (dendrites) as electrical inputs (called "spikes") that are channelled to outputs (axons). In our model, our dendrites are like the input features x1...xn, and the output is the result of our hypothesis function.In neural networks, we use the same logistic function as in classification, yet we sometimes call it a sigmoid (logistic) activation function. In this situation, our "theta" parameters are sometimes called "weights".

# %% [markdown]
# ![Screenshot%202022-04-20%20202255.png](attachment:Screenshot%202022-04-20%20202255.png)

# %% [markdown]
# Our input nodes (layer 1), also known as the "input layer", go into another node (layer 2), which finally outputs the hypothesis function, known as the "output layer".
# We can have intermediate layers of nodes between the input and output layers called the "hidden layers."
# In this example, we label these intermediate or "hidden" layer nodes a1^2, a2^2, ...an^2 and call them <font color='B3BFFF'>"activation units."</font>
#
#  ![Screenshot%202022-04-20%20201903.png](attachment:Screenshot%202022-04-20%20201903.png)
#  <a id="function"></a>

# %% [markdown]
# The values for each of the "activation" nodes is obtained as follows where g() is the sigmoid function :
#
# ![Screenshot%202022-04-20%20203103.png](attachment:Screenshot%202022-04-20%20203103.png)
#
# >
# <center> <video src="weight-matrix.mp4" width="618" height="317" controls id="myVideo"><center>

# %% [markdown]
# <center> <video src="weighted-sum.mp4" width="618" height="317" controls id="myVideo"><center>

# %% [markdown]
# ###       <font color='454545'>Forward Propagation: vectorized implementation</font>
# <a id="weighted"></a>
#
# In this section we'll do a vectorized implementation of the above [function](#function). We're going to define a new variable Zk^(j) that encompasses the parameters inside our g function.

# %% [markdown]
# ![Screenshot%202022-04-120%20203103.png](attachment:Screenshot%202022-04-120%20203103.png)

# %% [markdown]
#
#  In our previous [example](#function) if we replaced by the variable z for all the parameters we would get:
#
#  ![Screenshot%202022-04-20%20212238.png](attachment:Screenshot%202022-04-20%20212238.png)

# %% [markdown]
# The vector representation of x and z^j is:
#
# ![Screenshot%202022-04-20%20212509.png](attachment:Screenshot%202022-04-20%20212509.png)

# %% [markdown]
# ## <font color='454545'>Hand-Drawn Digits Identification problem</font>

# %% [markdown]
# Somehow identifying digits is incredibly easy for your brain to do, but almost impossible to describe how to do. The traditional methods of computer programming, with if statements and for loops and classes and objects and functions, just don’t seem suitable to tackle this problem.
#
# But what if we could write a program that mimics the structure of your brain? That’s the idea behind neural networks. The hope is that by writing brain-inspired software, we might be able to create programs that tackle the kinds of fuzzy and difficult-to-reason-about problems that your mind is so good at solving.
#
# we don't give the program any specific instructions for how to identify digits. Instead, we’ll show it many examples of hand-drawn digits together with labels for what they should be, and leave it up to the computer to adapt the network based on each new example.

# %% [markdown]
# ### <font color='454545'>Structure of the Identification Neural Network</font>
#
# the Hand_Drawn Digits examples are feed to the system using pictures.
# we will use the neural network in the figure to demonstrate the basic ideas of the neural network structure.

# %% [markdown]
# <a id="example"></a>
# ![Screenshot%202022-04-21%20000916.png](attachment:Screenshot%202022-04-21%20000916.png)

# %% [markdown]
# ## 1.<font color='454545'>Neurons</font>
#
# here we want to think of neurons as “a thing that holds a number.” Specifically, a number between 0.0 and 1.0.
#
# This number inside the neuron is called the “activation” of that neuron, and the image you might have in your mind is that each neuron is lit up when its activation is a high number.
#
# all the information passing through our neural network is stored in these neurons. So we need to represent the inputs and outputs of our network (the images and digit predictions).
#
# ![Screenshot%202022-04-20%20224650.png](attachment:Screenshot%202022-04-20%20224650.png)

# %% [markdown]
# ## <font color='454545'>2. Layers</font>
#   #### <font color='454545'>2.1 the Input Layer</font>
#
# The number of neurons on the first layer will depend on the amount of pixels in our image for ex: if our digit images have 28×28=784 pixels there will be 784 neurons, each with a brightness value between 0.0 and 1.0 on the greyscale with white being 1.0 and black being 0.0. To represent this in the network, we’ll create an input layer of 784 neurons, where each neuron corresponds to a particular pixel.

# %% [markdown]
# ![Screenshot%202022-04-20%20230330.png](attachment:Screenshot%202022-04-20%20230330.png)
# <a id="graph"></a>

# %% [markdown]
# <center> <video src="pixels-to-neurons.mp4" width="618" height="317" controls id="myVideo"><center>

# %% [markdown]
# #### <font color='454545'>2.2 The Output Layer</font>
# The last layer of our network will have 10 neurons, each representing one of the possible digits. The activation in these neurons, again some number between 0.0 and 1.0, will represent how much the system thinks an image corresponds to a given digit.

# %% [markdown]
# #### <font color='454545'>2.3 The Hidden Layers</font>
#
# In this [example](#example) I have 2 hidden layers, each with 16 neurons, choosing the correct amount of neurons and hidden layers is admittedly kind of an arbitrary choice. the amount of layer needs to be chosen based on how we want to motivate the structure in just a moment, and the number of neurons depends on the amount of data that we have. In practice, there’s a lot of room to experiment with the specific structure.

# %% [markdown]
# > You’ll notice how in these drawings each neuron from one layer is connected to each neuron of the next with a little line. This is meant to indicate how the activation of each neuron in one layer, the little number inside it, has some influence on the activation of each neuron in the next layer.
#
# <center> <video src="network-propagation.mp4" width="618" height="317" controls id="myVideo"><center>
#
# Some of these connections will be stronger than others, and as you’ll see shortly, determining how strong these connections are is really the heart of how a neural network operates, as an information processing mechanism.

# %% [markdown]
# ## <font color='454545'>3. How the network Recognizes the Digits</font>
#
# let’s talk about why it’s even reasonable to expect a layered structure like this to behave intelligently.
# when you or I recognize digits, we piece together various components like loops and lines.
#
# ![Screenshot%202022-04-21%20004456.png](attachment:Screenshot%202022-04-21%20004456.png)
#
# In an ideal world, we might hope that each neuron in the second-to-last layer corresponds to one of these subcomponents. That anytime you feed in an image with, say, a loop up top, there is some specific neuron whose activation will be close to 1.0.
# That way, going to the last layer would only require learning which combinations of subcomponents correspond to which digits.
#
# the true problem is how would you recognize these subcomponents?

# %% [markdown]
# ### <font color='454545'>3.1 Recognizing the Subcomponents</font>
#
# Recognizing a loop can also break down into subproblems. One reasonable way to do that would be to first recognize the various edges that make it up.

# %% [markdown]
# ![Screenshot%202022-04-21%20005251.png](attachment:Screenshot%202022-04-21%20005251.png)
#
# each neuron in the second layer of the network corresponds to some little edge. Maybe when an image comes in, it lights up neurons associated with all the specific little edges inside that image. This, in turn, would light up the neurons in the third layer associated with larger scale patterns like loops and long lines, which would then cause some neuron from the final layer to fire which corresponds to the appropriate digit.

# %% [markdown]
# ## <font color='454545'>4. How Information Passes Between Layers</font>
#
# how do you actually implement information passing?
# we need a mechanism that could conceivably combine pixels into edges, or edges into patterns, or patterns into digits. It would be ideal if all of those different steps used the same mathematical procedure.
#
# let’s say that the hope is for this one particular neuron in the second layer to pick up on whether or not the image has an edge in this spot here:
#
# <a id="weight"></a>
#  ![Screenshot%202022-04-21%20013745.png](attachment:Screenshot%202022-04-21%20013745.png)
#
#  parameters of the network should allow us to tweak the knobs and dials, so that it’s expressive enough to potentially capture this pattern. Or other pixel patterns. Or the pattern that several edges can make a loop, and other such things.
#
# What we’ll do is assign a [weight](#weight) to each of the connections between our neuron and the neurons from the first layer. These weights are just numbers.
#
# Each weight is an indication of how its neuron in the first layer is correlated with this new neuron in the second layer.
# If the neuron in the first layer is on, then a positive weight suggests that the neuron in the second layer should also be on, and a negative weight suggests that the neuron in the second layer should be off.
#
# to compute the value of this second-layer neuron, you take all the activations from the neurons in the first layer, and compute their [weighted](#function) sum = w11 x a1^1 + w12 x a2^1 + w13 x a3^1 ........w1n x an^1.
#
# we can use a grid to represent the weighs of each node:

# %% [markdown]
# ![Screenshot%202022-04-21%20015950.png](attachment:Screenshot%202022-04-21%20015950.png)
#
#
# What if we made the weights associated with almost all the pixels 0, except for some positive weights(red) associated with these pixels in the region where we want to detect an edge?
#
# Then taking a weighted sum of all pixel values really just amounts to adding up the values of the pixels in this region we care about.
#
# But this pattern of weights will also pick up on big blobs of activated pixels! (Not just edges.) To really pick up on whether or not this is an edge, you might want to have some negative weights associated with the surrounding pixels (blue). Then the sum will be largest when these pixels are bright, but the surrounding pixels are dark.

# %% [markdown]
# ![Screenshot%202022-04-21%20023839.png](attachment:Screenshot%202022-04-21%20023839.png)

# %% [markdown]
# ## <font color='454545'>5. Sigmoid Squishification</font>
#
# The result of the weighted sum like this can be any number, but for this network we want the activations to be values between 0 and 1. So it’s common to pump this weighted sum into some function that squishes the real number line into the range between 0 and 1.
# >
# <center> <video src="number-line-squish%20(1).mp4" width="618" height="317" controls id="myVideo"><center>

# %% [markdown]
# One common function that does this is called the “sigmoid” function, also known as a logistic curve, which we represent using the symbol σ. Very negative inputs end up close to 0, very positive inputs end up close to 1, and it steadily increases around 0. So the activation of the neuron here will basically be a measure of how positive the weighted sum is.
#
# ![Screenshot%202022-04-21%20025044.png](attachment:Screenshot%202022-04-21%20025044.png)

# %% [markdown]
# ## <font color='454545'>6. The cost function</font>
#
# Remember, our network's behaviour is determined by all of its weights and biases. The weights represent the strength of connections between each neuron in one layer and each neuron in the next. And each bias is an indication of whether its neuron tends to be active or inactive.
#
# when we start things off, we initialize all the weights and biases to be random numbers. This network will perform horribly on the given training example since it’s just doing something random.
#
# In order to improve the output, we need the system to programmatically identify that the computer is doing a lousy job and that it needs help.
#
# The cost function is used to measure the correctness of the system in comparison to the actual output, that is done by adding up the squares of the differences between each of these bad output activations and the values you want them to have. this is called the "cost" of a single training example.
#
# The cost is small when the network confidently classifies this image correctly but large when it doesn’t know what it’s doing.
#
# ![Screenshot%202022-04-21%20183638.png](attachment:Screenshot%202022-04-21%20183638.png)

# %% [markdown]
# ###  <font color='454545'>6.1 Minimizing The cost fucntion</font>
#
# But we aren’t just interested in how the network performs on a single image. To really measure its performance, we need to consider the average cost over all the tens of thousands of training examples. This average is our measure of how lousy the network is and how bad the computer should feel. This is, to put it lightly, a complicated function. Remember how the network itself is a function? It has 784 inputs (the pixel values), 10 outputs, and 13,002 parameters.
#
# The cost function is a layer of complexity on top of that. The inputs of the cost function are those 13,002 weights and biases, and it spits out a single number describing how bad those weights and biases are.
#
# To make it easier, rather than struggling to imagine this cost function with 13,002 inputs, let’s imagine a simple function with one number as an input, and one number as an output.
#
# How do you find an input that minimizes the value of this cost function?
#
# you can sometimes figure out that minimum explicitly by solving for when the slope is zero. However, that’s not always feasible for really complicated functions, and it certainly won’t be for our 13,002-input function defined in terms of an ungodly number of parameters.
#
# A more flexible tactic is to start at a random input and figure out which direction to step to make the output lower. Specifically, find the slope of the function where you are. If the slope is negative, shift to the right. If the slope is positive, shift to the left.
#
# Checking the new slope at each point and doing this repeatedly, you approach some local minimum of the function.
# >
# <center> <video src="follow-slope.mp4" width="618" height="317" controls id="myVideo"><center>

# %% [markdown]
# for this simplified single-input cost function, there are many possible valleys you might land in. It depends on which random input you start at, and there’s no guarantee that the local minimum you land in will be the smallest possible value for the cost function.
#
# ###  <font color='454545'>6.2 Using The Gradient</font>
#
# Bumping up the complexity a bit, imagine a function with two inputs and one output. You might think of the input space as the xy-plane, with the cost function graphed as a surface above it. Instead of asking about the slope of the function, you ask which direction you should step in this input space to decrease the output of the function most quickly, to do that a vector to represent the direction of steepest ascent is used in calculus this is known as the “gradient”, and it tells you which direction you should step to increase the function most quickly, taking the negative of that vector gives you the direction to step which decreases the function most quickly. What’s more, the length of that gradient vector is an indication for just how steep that steepest slope is.
#
# So the algorithm for minimizing this function is to compute this gradient direction, take a step downhill, and repeat that over and over. This process is called “gradient descent.”
#
# ![Screenshot%202022-04-21%20195012.png](attachment:Screenshot%202022-04-21%20195012.png)

# %% [markdown]
# In practice, each step will look like −η∇C where the constant η is known as the learning rate. The larger it is, the bigger your steps, which means you might approach the minimum faster, but there’s a risk of overshooting and oscillating a lot around that minimum.

# %% [markdown]
# ## <font color='454545'>7. How the Network Learns</font>
#
# ## <font color='454545'>7.1 Train and Test </font>
#
#
# we don't actually write an algorithm for recognizing digits. Instead, we write an algorithm that can take in a bunch of example images of handwritten digits along with labels for what they are and adjust those 13,002 weights and biases of the network to make it perform better on those examples and this is collectively known as the "training data".
#
# ![Screenshot%202022-04-21%20164412.png](attachment:Screenshot%202022-04-21%20164412.png)
#
# This process requires a lot of data. Fortunately the MINST dataset contains a collection of tens of thousands of handwritten digit images, each labeled with the number they are supposed to be, that we can use.
# <a id="codeimp"></a>

# %%
# !pip install mnist
# !pip install opencv-python
import numpy as np
import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
from keras.optimizers import gradient_descent_v2
from keras.optimizers import adam_v2 as Adam
from keras.layers import Dropout
import matplotlib.pyplot as plt
import cv2 
from keras.callbacks import EarlyStopping

# %% [markdown]
# Eventually, the layered structure will know that what it learns generalizes to images beyond the training data. To test this, after training the network, we can show it more labeled data that it’s never seen before and see how accurately it classifies them.

# %%
# spliting the data into train and test groups
train_images = mnist.train_images()
train_labels = mnist.train_labels()
test_images = mnist.test_images()
test_labels = mnist.test_labels()

# %% [markdown]
# ## <font color='454545'>7.2 Scaling the data</font>
#
# the MNIST dataset has 28x28 pixel images with pixel values in the range [0, 255], we scale the data Because it retains enough information, it saves lots of computation time and reduces the number of parameters, making it easier to train.
# so we use the following code to scale the data to the [0,1] range.

# %%
# Scale the images.
train_images = (train_images / 255) 
test_images = (test_images / 255)

# %% [markdown]
# the next thing that need to be done is to flatten our dataset and the best way to visualize this is to look at this [animation](#graph).

# %%
# Flatten the images.
train_images = train_images.reshape((60000, 784))
test_images = test_images.reshape((10000, 784))

# %% [markdown]
# ## <font color='454545'>7.3 Building and compiling our model</font>
#
# ### Building the model
#
# our artificial neural network is an instance of the Sequential class, The Sequential class lives within the models module of the keras library.
#
# [code](#codeimp)  <font color='green'>from</font> tensorflow.keras.models <font color='green'>import</font> Sequential
#
# #### Identifying the layers
#
# Let's start by discussing the input layer. No action is required here as they are entirely decided by the data set that the model is trained on. We do not need to specify our input layer.
# keras contains a module called layers that contains pre-built classes for the different types of neural network layers you might want to add to your model.
#
# [code](#codeimp)  <font color='green'>from</font> tensorflow.keras.layers <font color='green'>import</font> Dense
#
# ##### Parameters passed to the Dense Class
# The first parameter we need to pass to the Dense class is the number of neurons you'd like to include in the new layer of your neural net.
#
# the second parameter that is passed to the class is the neural network's activation function. By default, there is no activation function applied in the Dense layer. This means that the weighted sum of input values is simply passed on to the next layer of the network, In our case, we'll be using the Rectified Linear Unit (ReLU) activation function and the softmax function, we arenot using the sigmoid function because it saturates. This means that large values snap to 1.0 and small values snap to 0. Further, the function is only really sensitive to changes around the mid-point of its input, such as 0.5.
#
# The limited sensitivity and saturation of the function happen regardless of whether the summed activation from the node provided as input contains useful information or not. Once saturated, it becomes challenging for the learning algorithm to continue to adapt the weights to improve the performance of the model..
#
# ###### The rectified linear activation function:
#
# The rectified linear activation function or ReLU is a piecewise linear function that will output the input directly if it is positive, otherwise, it will output zero. ex: The rectified linear activation function is a simple calculation that returns the value provided as input directly, or the value 0.0 if the input is 0.0 or less. It has become the default activation function for many types of neural networks because a model that uses it is easier to train and often achieves better performance.
#
# ###### SoftMax activation function:
#
# The Softmax activation function normalizes outputs by assigning probabilities to the sum of weighted values such that the sum of probabilities is equal to 1. Thus each class has its own probability distribution in the class membership. The Softmax function can then be described as the mathematical function converting the output into probability vector numbers from the input vector numbers with each vector value’s probabilities proportional to its relative value vector scale.
#
# ##### The Dropout layer
# Dropout Layer is one of the most popular regularization techniques to reduce overfitting in the deep learning models. Overfitting in the model occurs when it shows more accuracy on the training data but less accuracy on the test data or unseen data, some of the neurons in hidden or visible layers are dropped or omitted randomly. The dropout technique regularizes the neural network model to produce a robust model which does not overfit. here we only pass the rate which represents the fraction of the input unit to be dropped.

# %%
# Build the model.
model = Sequential([Dense(64, activation='relu', input_shape=(784,)),
                    Dense(128, activation='relu'),
                    Dropout(0.5),
                    Dense(10, activation='softmax')
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\LENOVO~1\AppData\Local\Temp/ipykernel_20108/2435117160.py in <module>
#       1 # Build the model.
# ----> 2 model = Sequential([Dense(64, activation='relu', input_shape=(784,)),
#       3                     Dense(128, activation='relu'),
#       4                     Dropout(0.5),
#       5                     Dense(10, activation='softmax')
#
# NameError: name 'Sequential' is not defined

# %% [markdown]
# ### Compiling the model
#
# When training a neural network, its weights are initially initialized randomly and then they are updated in each epoch in a manner such that they increase the overall accuracy of the network. In each epoch, the output of the training data is compared to actual data with the help of the loss function to calculate the error and then the weight is updated accordingly such that it increases the accuracy.
#
# This is essentially an optimization problem where the goal is to optimize the loss function, The method used for optimization is known as Optimizer. Gradient Descent is the most widely known but there are many other optimizers that are used for practical purposes and they all are available in Keras, and the stepsis to Create an instance of the optimizer in Keras and use it while compiling the method. Directly pass the string identifier for the Optimizer while compiling the method.
#
# ###### The Cross Entropy loss function
#
# The Cross Entropy loss function is an optimization function which is used in case of training a classification model which classifies the data by predicting the probability of whether the data belongs to one class or the other class. Keras provide the following three different types of cross entropy loss function: binary_crossentropy, sparse_categorical_crossentropy and
# categorical_crossentropy.
#
# ###### categorical_crossentropy.
#
# categorical_crossentropy is used as a loss function for multi-class classification model where there are two or more output labels. The output label is assigned one category encoding value in form of 0s and 1. The output label, if present in integer form, is converted into categorical encoding using keras.utils to_categorical method.
#
# ![Screenshot%202022-04-28%20052221.png](attachment:Screenshot%202022-04-28%20052221.png)

# %% [markdown]
# ###### The performance metrics
#
# A metric is a function that is used to judge the performance of your model. Metric functions are similar to loss functions, except that the results from evaluating a metric are not used when training the model.
#
# ###### The Accuracy Metric
#
# The Accuracy Metric Calculates how often predictions equal labels. This metric creates two local variables, <font color='blue'>total</font> and <font color='blue'>count</font> that are used to compute the frequency with which y_pred matches y_true. This frequency is ultimately returned as binary accuracy: an idempotent operation that simply divides total by count.
#
# ![Screenshot%202022-04-28%20143559.png](attachment:Screenshot%202022-04-28%20143559.png)

# %%
# Compile the model.
SGD = gradient_descent_v2.SGD(learning_rate=0.01)
model.compile(optimizer=SGD, loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ###### The early stopping call  back
#
# The early stopping call  back allows you to specify the performance measure to monitor the trigger, and once triggered, it will stop the training process.
#
# The model tries to chase the loss function crazily on the training data, by tuning the parameters. Now, we keep another set of data as the validation set and as we go on training, we keep a record of the loss function on the validation data, and when we see that there is no improvement on the validation set, we stop, rather than going all the epochs.
#
# The “monitor” allows you to specify the performance measure to monitor in order to end training. Stop training when a monitored metric has stopped improving.

# %%
#create the call backs
early=EarlyStopping(monitor='val_loss' , mode='auto' , patience=2)

# %% [markdown]
# ##### Parameters of Fit()
#
# - object : the model to train.
# > X : our training data. Can be Vector, array or matrix
# > Y : our training labels. Can be Vector, array or matrix
#
# - Epochs : an integer and number of epochs we want to train our model for.
#
# - Batch_size : it can take any integer value or NULL and by default, it will be set to 32. It specifies no. of samples per    gradient.
#
# - callbacks : a list of callback functions applied during the training of our model.
#
# - validation_data can be either:
#                       - an inputs and targets list
#                       - a generator
#                       - an inputs, targets, and sample_weights list which can be used to evaluate
#                         the loss and metrics for any model after any epoch has ended.

# %%
# Train the model.
history=model.fit(train_images,
                  to_categorical(train_labels),
                  epochs=30,
                  batch_size=32 ,
                  validation_data=(test_images , to_categorical(test_labels)) ,
                  callbacks=[early]
)
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.9166 - accuracy: 0.7220 - val_loss: 0.3616 - val_accuracy: 0.9003
# Epoch 2/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4205 - accuracy: 0.8794 - val_loss: 0.2715 - val_accuracy: 0.9252
# Epoch 3/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.3363 - accuracy: 0.9045 - val_loss: 0.2314 - val_accuracy: 0.9368
# Epoch 4/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2952 - accuracy: 0.9175 - val_loss: 0.2049 - val_accuracy: 0.9422
# Epoch 5/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2623 - accuracy: 0.9265 - val_loss: 0.1855 - val_accuracy: 0.9459
# Epoch 6/30
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2399 - accuracy: 0.9327 - val_loss: 0.1722 - val_accuracy: 0.9493
# Epoch 7/30
# ...

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
img=test_images[0].reshape((1,784)) #create batch of 1
plt.imshow(test_images[0].reshape((28,28)))
test_labels[0]
# Out:
# 7

# %%
np.argmax(model.predict(img))
# Out:
# 7
